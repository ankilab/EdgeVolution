# %%
import numpy as np
import sys
import matplotlib.pyplot as plt

sys.path.append('../../datasets')
from load_data import get_datasets

from nutil.plot import paperStyle

# %%
ds_train, ds_val, ds_test, class_weights = get_datasets("emg_airob")
# Out:
# Loading train data: 100%|██████████| 3/3 [00:01<00:00,  2.93it/s]
# Loading val data: 100%|██████████| 2/2 [00:00<00:00,  2.74it/s]
# Loading test data: 100%|██████████| 1/1 [00:00<00:00,  5.22it/s]
# 2025-01-30 14:48:06.623062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.643447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.645195: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.647126: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-30 14:48:06.648107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.649772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.651358: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.771937: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.773591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.775157: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-01-30 14:48:06.776706: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21788 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
i = 0
for X, y in ds_train.take(20):
    if i == 4:
        with paperStyle():
            plt.figure(figsize=(0.5, 0.5))
            plt.imshow(X)
            plt.axis('off')
            
            plt.savefig('emg.svg', bbox_inches='tight', dpi=300)
            plt.show()
        break
    i += 1
