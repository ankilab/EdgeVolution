# %%
import json
from src.translation import translate
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
from src.genepool import GenePool
gene_pool = GenePool()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_145641/1226454097.py in <module>
#       1 from src.genepool import GenePool
# ----> 2 gene_pool = GenePool()
#
# TypeError: __init__() missing 1 required positional argument: 'params'

# %%
#for _ in range(50):
gene_sequence = gene_pool.get_random_gene_sequence()
m = translate(input_shape=(64, 64, 1), gene_sequence=gene_sequence)
m.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_145641/4271567929.py in <module>
#       1 #for _ in range(50):
# ----> 2 gene_sequence = gene_pool.get_random_gene_sequence()
#       3 m = translate(input_shape=(64, 64, 1), gene_sequence=gene_sequence)
#       4 m.summary()
#
# NameError: name 'gene_pool' is not defined

# %%
d = [{'test': 123, 'hallo': 'moin'}, {'test': 123, 'hallo': 'moin'}]

# %%
with open("test.txt", 'w') as f:
    f.write(str(d))
