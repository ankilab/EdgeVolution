# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("power_measurements_1050242564.csv")

# %%
df
# Out:
#        Power Consumption
# 0              -1.477053
# 1              -1.477053
# 2              -1.564121
# 3              -1.520587
# 4              -1.564121
# ...                  ...
# 65515        3470.098295
# 65516        3614.257185
# 65517        3535.106767
# 65518        3642.248026
# 65519        3377.502030
#
# [65520 rows x 1 columns]

# %%
df["Power Consumption"][0::].plot()
plt.ylabel("Current Consumption (uA)")
plt.ylim(0, 14000)
# Out:
# (0.0, 14000.0)
