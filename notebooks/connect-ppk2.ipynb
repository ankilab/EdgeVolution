# %%
import sys
sys.path.append('../')
from tools.measure_power_consumption import get_ppk_port, init_ppk2

# %%
ppk2_serial = "E373C904"

# %%
get_ppk_port(ppk2_serial)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /data/du92wufe/Documents/EvoNAS/notebooks/connect-ppk2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.203.25.185/data/du92wufe/Documents/EvoNAS/notebooks/connect-ppk2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> get_ppk_port(ppk2_serial)
#
# File ~/Documents/EvoNAS/tools/measure_power_consumption.py:40, in get_ppk_port(ppk_serial)
#      38 # raise error if no device is found
#      39 if len(devices) == 0:
# ---> 40     raise RuntimeError(f"The ppk with serial number {ppk_serial} does not seem to be connected")
#      42 # raise error if more than 1 device is found. means that there are two ppks with same serial number or the first 8 digits are not sufficient to uniquely identify ppk
#      43 if len(devices) > 1:
#
# RuntimeError: The ppk with serial number E373C904 does not seem to be connected

# %%
init_ppk2(ppk2_serial)
