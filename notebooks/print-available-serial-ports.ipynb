# %%
import serial
import serial.tools.list_ports

# %%
ports = serial.tools.list_ports.comports()
[print(port, port.description) for port in ports]
# Out:
# /dev/ttyS0 - ttyS0 ttyS0
# /dev/ttyACM10 - PPK2 PPK2
# /dev/ttyACM9 - PPK2 PPK2
# /dev/ttyACM8 - J-Link - CDC J-Link - CDC
# /dev/ttyACM7 - J-Link - CDC J-Link - CDC
# /dev/ttyACM6 - nrf52840dk_nrf52840-1050283223 nrf52840dk_nrf52840-1050283223
# /dev/ttyACM5 - J-Link - CDC J-Link - CDC
# /dev/ttyACM4 - J-Link - CDC J-Link - CDC
# /dev/ttyACM3 - nrf5340dk_nrf5340_cpuapp-1050006605 nrf5340dk_nrf5340_cpuapp-1050006605
# /dev/ttyACM2 - J-Link - CDC J-Link - CDC
# /dev/ttyACM1 - J-Link - CDC J-Link - CDC
# /dev/ttyACM0 - J-Link - CDC J-Link - CDC
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
# check if port dev/ttyACM3 is available
port = '/dev/ttyACM4'
ser = serial.Serial(port, 9600, timeout=1)

# %%
2
