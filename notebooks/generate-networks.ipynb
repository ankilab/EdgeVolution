# %%
import yaml

# %%
config_file_path = '../config.yaml'  # Replace with the path to your YAML file
with open(config_file_path, 'r') as yaml_file:
    config = yaml.safe_load(yaml_file)

# %%
config["DATASETS"]
# Out:
# ['speech_commands', 'motion_sense_accelerometer']
