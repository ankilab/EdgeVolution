# %%
import json
import sys
import os
import time
sys.path.append('../')
from tools.measure_power_consumption import get_ppk_port, init_ppk2, measure_power_nrf, stop_measuring

from pathlib import Path

# %%
for i in range(10):
    print(i)
    ppk2_serial = "FEA55411"
    get_ppk_port(ppk2_serial)
    ppk2 = init_ppk2(ppk2_serial)
    ppk2.start_measuring()
    
    time.sleep(1)
    ppk2.stop_measuring()
    time.sleep(1)
    
    del ppk2
    time.sleep(5)
    
    ppk2 = init_ppk2(ppk2_serial)
    time.sleep(5)
# Out:
# 0
# Tried to connect to PPK2 with serial FEA55411. Waiting 2 seconds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/EvoNAS/tools/measure_power_consumption.py:89, in init_ppk2(ppk_serial, timeout_in_s)
#      88 _ppk2.set_source_voltage(3300); time.sleep(0.1) # set source voltage
# ---> 89 _ppk2.toggle_DUT_power("ON"); time.sleep(0.1)  # enable DUT power
#      91 # start measuring
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 ppk2_serial = "FEA55411"
#       4 get_ppk_port(ppk2_serial)
# ----> 5 ppk2 = init_ppk2(ppk2_serial)
#       6 ppk2.start_measuring()
#       8 time.sleep(1)
#
# File ~/Documents/EvoNAS/tools/measure_power_consumption.py:104, in init_ppk2(ppk_serial, timeout_in_s)
#     101 _ppk2.stop_measuring()
#     103 # delay after unsuccessful try
# --> 104 time.sleep(delay_in_s)
#     106 # make sure to not be in an infinity loop if the error won't go away
#     107 i += 1
#
# KeyboardInterrupt:

# %%
ppk2_serial = "FEA55411"
get_ppk_port(ppk2_serial)
_ppk2 = init_ppk2(ppk2_serial)

# %%
del _ppk2

# %%
# Connect PPK2 board --> this is sufficient to enable the functionalities of the nRF DK board (alternative: use the nRF connect for Desktop tool)
ppk2_serial = "FEA55411"
get_ppk_port(ppk2_serial)
ppk2 = init_ppk2(ppk2_serial)
# Out:
# Tried to connect to PPK2 with serial FEA55411. Waiting 2 seconds.
# Tried to connect to PPK2 with serial FEA55411. Waiting 2 seconds.
# Tried to connect to PPK2 with serial FEA55411. Waiting 2 seconds.
# KeyboardInterrupt

# %%
# Create dummy results.json file, otherwise the power measurement will throw an error
path = Path("results.json")
if not path.exists():
    with path.open("w") as f:
        d = {"no_results": None}
        json.dump(d, f)

# %%
 measure_power_nrf(ppk2, ".", "1050242564", "FEA55411", 10)

# %%
stop_measuring(ppk2)

# %%
del ppk2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del ppk2
#
# NameError: name 'ppk2' is not defined

# %%
# Clean-up files in the 'notebook' dir
for f in os.listdir("."):
    if ".json" in f or ".csv" in f:
        os.remove(f)

# %%
d = {"axel": {'a': 1, 'b': 2}, "julian": {'a': 1, 'b': 2}}

# %%
x = list(d.keys())[0]
x
# Out:
# 'axel'

# %%
d[x]
# Out:
# {'a': 1, 'b': 2}
